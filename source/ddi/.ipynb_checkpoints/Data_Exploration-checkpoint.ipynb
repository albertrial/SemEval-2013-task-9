# %%
import os
import nltk
from nltk.tokenize import word_tokenize
from nltk.parse.corenlp import CoreNLPDependencyParser
import xml.etree.ElementTree as ET
import nltk
from nltk.corpus import stopwords
import string
sw = stopwords.words('english')

# %%
path = '../../data/Train'

# %%
def sum_one(dictionary, key):
    if key in dictionary:
        dictionary[key] += 1
    else:
        dictionary[key] = 1

# %%
my_parser = CoreNLPDependencyParser(url="http://localhost:9000")

drug_dict = {'effect': 
                    {'clue_words':{},
                     'sentence_words':{},
                     'e1_under':{},
                     'e2_under':{},
                     'e1_under_e2':0,
                     'e1_e2_under_same_verb':0,
                     'e1_e2_under_same_word':0,
                     'e2_under_e1':0,
                     'rel': {},
                     'total':0
                    },
                 'mechanism':
                    {'clue_words':{},
                     'sentence_words':{},
                     'e1_under':{},
                     'e2_under':{},
                     'e1_under_e2':0,
                     'e1_e2_under_same_verb':0,
                     'e1_e2_under_same_word':0,
                     'e2_under_e1':0,
                     'rel': {},
                     'total':0
                    },
                 'int':
                    {'clue_words':{},
                     'sentence_words':{},
                     'e1_under':{},
                     'e2_under':{},
                     'e1_under_e2':0,
                     'e1_e2_under_same_verb':0,
                     'e1_e2_under_same_word':0,
                     'e2_under_e1':0,
                     'rel': {},
                     'total':0
                    },
                 'advise':
                    {'clue_words':{},
                     'sentence_words':{},
                     'e1_under':{},
                     'e2_under':{},
                     'e1_under_e2':0,
                     'e1_e2_under_same_verb':0,
                     'e1_e2_under_same_word':0,
                     'e2_under_e1':0,
                     'rel': {},
                     'total':0
                    },
                 'none':
                    {'clue_words':{},
                     'sentence_words':{},
                     'e1_under':{},
                     'e2_under':{},
                     'e1_under_e2':0,
                     'e1_e2_under_same_verb':0,
                     'e1_e2_under_same_word':0,
                     'e2_under_e1':0,
                     'rel': {},
                     'total':0
                    }
                }
total_pairs = 0
total_interactions = 0

for filename in os.listdir(path):
    print(filename)
    fullname = os.path.join(path, filename)
    tree = ET.parse(fullname)
    root = tree.getroot() 
        
    for s in root.findall('sentence'):
        sid = s.get('id') # get sentence id
        stext = s.get('text') # get sentence text
        
        if stext == "":
            continue
        
        
        # load sentence entities into a dictionary
        entities = {}
        ents = s.findall('entity')
        for e in ents :
            id = e.get('id')
            offs = e.get('charOffset').split("-")
            entities[id] = offs
        
        mytree, = my_parser.raw_parse(stext)
    
        pairs = s.findall('pair')
        for p in pairs:
            id_e1 = p.get('e1')
            id_e2 = p.get('e2')
            ddi = p.get('ddi')
        
            total_pairs += 1
            start1 = int(entities[id_e1][0].split(';')[0])
            end1 = int(entities[id_e1][1].split(';')[0])
            
            start2 = int(entities[id_e2][0].split(';')[0])
            end2 = int(entities[id_e2][1].split(';')[0])
            
            entity1 = stext[start1:end1+1]
            entity2 = stext[start2:end2+1]
        
            
            if ddi == "true":
                total_interactions += 1
                ddi_type = p.get('type')
                if ddi_type is None:
                    ddi_type = 'none'
            else:
                ddi_type = 'none'
                
            # Total
            drug_dict[ddi_type]['total'] += 1
            
            sentence_between = [word for word in word_tokenize(stext[end1+1:start2]) if word not in sw and word not in string.punctuation]
            
            for word in sentence_between:         
                sum_one(drug_dict[ddi_type]['clue_words'], word)

            all_other_sentence = [word for word in word_tokenize(stext[:start1] + ' ' + stext[end1+1:start2] + ' ' + stext[end2+1:]) if word not in sw and word not in string.punctuation]
            for word in all_other_sentence:
                sum_one(drug_dict[ddi_type]['sentence_words'], word)
                
                
            head1 = ''
            head2 = ''
            tag1 = ''
            tag2 = ''
            for k in mytree.nodes:
                if mytree.nodes[k]['word'] == entity1 or mytree.nodes[k]['lemma'] == entity1:
                    h1 = mytree.nodes[k]['head']
                    head1 = mytree.nodes[h1]['lemma']
                    tag1 = mytree.nodes[h1]['tag'][0].lower()
                    
                elif mytree.nodes[k]['word'] == entity2 or mytree.nodes[k]['lemma'] == entity2:
                    h2 = mytree.nodes[k]['head']
                    head2 = mytree.nodes[h2]['lemma']
                    tag2 = mytree.nodes[h2]['tag'][0].lower()
            
            if head1 == head2 and tag1 == 'v' and tag2 == 'v':
                drug_dict[ddi_type]['e1_e2_under_same_verb'] += 1
            
            if head1 == head2:
                drug_dict[ddi_type]['e1_e2_under_same_word'] += 1
                
            if head1 == entity2:
                drug_dict[ddi_type]['e1_under_e2'] += 1
            
            if head2 == entity1:
                drug_dict[ddi_type]['e2_under_e1'] += 1
            
            
            sum_one(drug_dict[ddi_type]['e1_under'], head1) 
            sum_one(drug_dict[ddi_type]['e2_under'], head2)
# Out:
#   File "<ipython-input-37-84a8de9d37c9>", line 119
#     for word in word_tokenize(stext[end1+1:start2]) if word not in sw and word not in string.punctuation:
#                                                                                                         ^
# SyntaxError: invalid syntax

# %%
print("# interactions", total_interactions)
print("# total", total_pairs)
print("-------")
print("# effect", drug_dict['effect']['total'])
print("# mechanism", drug_dict['mechanism']['total'])
print("# int", drug_dict['int']['total'])
print("# advise", drug_dict['advise']['total'])
print("# none", drug_dict['none']['total'])
# Out:
# # interactions 3537
# # total 25089
# -------
# # effect 1525
# # mechanism 1118
# # int 186
# # advise 707
# # none 21553

# %%
for t in ['effect', 'mechanism', 'int', 'advise', 'none']:
    print('-----------------------------------------------')
    print("TYPE", t)
    print("Clue_words")
    total = drug_dict[t]["total"]
    print(sorted(drug_dict[t]['clue_words'].items(), key=lambda item: item[1], reverse=True)[0:20])
    print("Words in sentence")
    print(sorted(drug_dict[t]['sentence_words'].items(), key=lambda item: item[1], reverse=True)[0:20])
    print("E1 under")
    print(sorted(drug_dict[t]['e1_under'].items(), key=lambda item: item[1], reverse=True)[0:20])
    print("E2 under")
    print(sorted(drug_dict[t]['e2_under'].items(), key=lambda item: item[1], reverse=True)[0:20])
    print("e1_e2_under_same_verb", drug_dict[t]['e1_e2_under_same_verb'], drug_dict[t]['e1_e2_under_same_verb']/total, '%')
    print("e1_e2_under_same_word", drug_dict[t]['e1_e2_under_same_word'], drug_dict[t]['e1_e2_under_same_word']/total, '%')
    print("e1_under_e2", drug_dict[t]['e1_under_e2'], drug_dict[t]['e1_under_e2']/total, '%')
    print("e2_under_e1", drug_dict[t]['e2_under_e1'], drug_dict[t]['e2_under_e1']/total, '%')
    print("total", total)
    print('-----------------------------------------------')
# Out:
# -----------------------------------------------
# TYPE effect
# Clue_words
# [(',', 2081), (';', 1842), ('of', 633), ('and', 608), ('the', 606), ('with', 462), ('may', 418), ('(', 298), (')', 291), ('other', 264), ('in', 242), ('to', 205), ('drugs', 201), ('or', 188), ('response', 171), ('acid', 163), ('effects', 161), ('by', 158), ('effect', 157), ('be', 149)]
# Words in sentence
# [(',', 4463), (';', 3702), ('of', 1615), ('.', 1490), ('and', 1348), ('the', 1168), ('may', 819), ('with', 759), ('in', 650), ('(', 644), (')', 638), ('or', 522), ('drugs', 475), ('other', 470), (':', 444), ('to', 443), ('effects', 339), ('as', 336), ('that', 296), ('acid', 292)]
# E1 under
# [('', 333), ('use', 91), ('response', 81), ('action', 54), ('effect', 48), ('administration', 48), ('agent', 44), ('enhance', 28), ('decrease', 26), ('increase', 26), ('administer', 25), ('have', 21), ('receive', 20), ('drug', 17), ('potentiate', 16), ('injection', 16), ('reduce', 15), ('Butalbital', 14), ('inhibitor', 13), ('interaction', 12)]
# E2 under
# [('', 412), ('effect', 131), ('allopurinol', 37), ('use', 30), ('agent', 28), ('action', 25), ('alcohol', 25), ('administration', 22), ('receive', 21), ('g.', 21), ('administer', 19), ('therapy', 19), ('activity', 17), ('analgesic', 17), ('anticoagulant', 16), ('antibiotic', 14), ('fluoxetine', 14), ('toxicity', 12), ('opioid', 12), ('drug', 11)]
# e1_e2_under_same_verb 23 0.015081967213114755 %
# e1_e2_under_same_word 157 0.10295081967213114 %
# e1_under_e2 0 0.0 %
# e2_under_e1 71 0.04655737704918033 %
# total 1525
# -----------------------------------------------
# -----------------------------------------------
# TYPE mechanism
# Clue_words
# [(',', 2802), ('of', 612), ('the', 520), ('and', 361), ('with', 312), ('(', 284), (')', 284), ('to', 228), ('may', 185), ('or', 173), (':', 140), ('in', 132), ('are', 121), ('as', 108), ('by', 108), ('concentrations', 100), ('a', 93), ('plasma', 91), ('following', 91), ('metabolism', 87)]
# Words in sentence
# [(',', 6125), ('of', 1647), ('.', 1080), ('and', 1004), ('the', 997), ('(', 718), ('in', 718), (')', 713), ('to', 547), ('with', 486), (':', 459), ('may', 389), ('a', 387), ('or', 383), ('plasma', 371), ('%', 351), ('that', 327), ('by', 320), ('are', 309), ('levels', 290)]
# E1 under
# [('', 135), ('concentration', 70), ('administration', 60), ('level', 52), ('presence', 46), ('increase', 38), ('decrease', 28), ('absorption', 26), ('use', 25), ('coadministration', 24), ('inhibit', 22), ('interfere', 22), ('metabolism', 20), ('co-administration', 17), ('know', 16), ('effect', 16), ('clearance', 15), ('blocker', 14), ('report', 13), ('dose', 13)]
# E2 under
# [('', 114), ('concentration', 66), ('level', 58), ('absorption', 44), ('clearance', 43), ('Acetaminophen', 43), ('metabolism', 35), ('auc', 28), ('coadminister', 24), ('antifungal', 23), ('intake', 21), ('administration', 19), ('exposure', 18), ('ketoconazole', 18), ('administer', 15), ('dose', 13), ('coadministration', 13), ('anticoagulant', 13), ('elimination', 12), ('bioavailability', 12)]
# e1_e2_under_same_verb 11 0.009838998211091235 %
# e1_e2_under_same_word 51 0.04561717352415027 %
# e1_under_e2 2 0.0017889087656529517 %
# e2_under_e1 37 0.03309481216457961 %
# total 1118
# -----------------------------------------------
# -----------------------------------------------
# TYPE int
# Clue_words
# [(',', 1009), ('(', 299), (')', 264), ('with', 134), ('and', 114), ('may', 99), ('interact', 97), ('the', 77), ('as', 66), (':', 64), ('following', 63), ('medications', 58), ('acetaminophen', 56), ('cyclosporine', 54), ('Tylenol', 54), ('such', 45), ('antibiotics', 43), ('e.g.', 42), ('ampicillin', 40), ('tetracycline', 39)]
# Words in sentence
# [(',', 2135), ('(', 668), (')', 668), ('and', 298), ('with', 190), ('.', 182), ('the', 148), ('may', 137), ('of', 134), ('as', 99), ('interact', 98), ('cyclosporine', 84), (':', 83), ('drugs', 82), ('medications', 75), ('e.g.', 72), ('following', 64), ('Tylenol', 57), ('acetaminophen', 56), ('such', 55)]
# E1 under
# [('interact', 86), ('interaction', 34), ('', 16), ('administration', 11), ('study', 7), ('other', 5), ('pharmacokinetic', 4), ('supplement', 4), ('have', 3), ('interfere', 3), ('drug', 2), ('level', 2), ('increase', 2), ('hydrate', 1), (None, 1), ('observe', 1), ('affect', 1), ('action', 1), ('administer', 1), ('preparation', 1)]
# E2 under
# [('', 34), ('carbamazepine', 12), ('interaction', 11), ('antidepressant', 11), ('cyclosporine', 10), ('ergotamine', 8), ('interact', 7), ('ampicillin', 7), ('inhibitor', 7), ('acetaminophen', 6), ('agenerase', 6), ('Dilantin', 5), ('preparation', 3), ('alcohol', 3), ('diltiazem', 2), ('antibiotic', 2), ('erythromycin', 2), ('therapy', 2), ('supplement', 2), ('medication', 2)]
# e1_e2_under_same_verb 5 0.026881720430107527 %
# e1_e2_under_same_word 22 0.11827956989247312 %
# e1_under_e2 0 0.0 %
# e2_under_e1 12 0.06451612903225806 %
# total 186
# -----------------------------------------------
# -----------------------------------------------
# TYPE advise
# Clue_words
# [(',', 739), ('with', 422), ('be', 269), ('and', 249), ('should', 234), ('or', 192), ('(', 184), ('of', 154), (')', 132), ('the', 120), ('in', 119), ('not', 110), ('administered', 105), ('is', 104), ('to', 100), ('other', 95), ('patients', 92), ('as', 86), ('such', 79), ('are', 76)]
# Words in sentence
# [(',', 1801), ('of', 721), ('.', 689), ('with', 589), ('be', 588), ('and', 501), ('should', 485), ('the', 440), ('or', 392), ('(', 361), (')', 358), ('is', 322), ('to', 252), ('in', 232), ('not', 198), ('as', 183), ('a', 178), ('patients', 153), ('other', 149), ('such', 141)]
# E1 under
# [('', 92), ('use', 75), ('administer', 71), ('administration', 40), ('take', 38), ('dose', 25), ('co-administration', 25), ('coadminister', 16), ('therapy', 15), ('coadministration', 13), ('receive', 13), ('treatment', 12), ('give', 10), ('concentration', 9), ('alfentanil', 9), ('dosage', 8), ('mg', 7), ('adjustment', 7), ('antibiotic', 7), ('solution', 6)]
# E2 under
# [('', 140), ('receive', 27), ('administer', 25), ('therapy', 23), ('dose', 18), ('coadminister', 18), ('use', 17), ('take', 16), ('ketoconazole', 15), ('combination', 15), ('give', 14), ('administration', 13), ('drug', 13), ('medication', 12), ('treatment', 12), ('level', 10), ('alcohol', 9), ('hour', 9), ('antidepressant', 8), ('coadministration', 7)]
# e1_e2_under_same_verb 29 0.04101838755304102 %
# e1_e2_under_same_word 78 0.11032531824611033 %
# e1_under_e2 1 0.0014144271570014145 %
# e2_under_e1 40 0.056577086280056574 %
# total 707
# -----------------------------------------------
# -----------------------------------------------
# TYPE none
# Clue_words
# [(',', 71573), (';', 30908), ('(', 11614), (')', 10953), ('and', 6842), ('of', 5677), ('the', 3744), ('acid', 3387), ('with', 2872), ('drugs', 2775), ('e.g.', 2442), ('or', 2422), ('in', 2356), ('inhibitors', 2319), (':', 2078), ('to', 1633), ('as', 1626), ('a', 1463), ('[', 1418), (']', 1405)]
# Words in sentence
# [(',', 203084), (';', 88699), (')', 33539), ('(', 33470), ('of', 22346), ('and', 21926), ('.', 19948), ('the', 16252), (':', 11738), ('with', 11643), ('in', 10525), ('or', 9980), ('drugs', 9482), ('acid', 8812), ('may', 8697), ('to', 8449), ('e.g.', 6894), ('that', 6483), ('inhibitors', 6149), ('as', 5404)]
# E1 under
# [('', 3636), (None, 1053), ('allopurinol', 1040), ('Acetaminophen', 935), ('antifungal', 377), ('effect', 307), ('use', 251), ('administration', 238), ('inhibitor', 227), ('acetaminophen', 227), ('ampicillin', 223), ('drug', 218), ('intake', 212), ('agonist', 205), ('interaction', 202), ('administer', 184), ('concentration', 184), ('dose', 172), ('include', 170), ('Dilantin', 170)]
# E2 under
# [('', 4555), ('Acetaminophen', 957), ('allopurinol', 871), ('antifungal', 402), ('agonist', 389), ('inhibitor', 350), ('effect', 246), ('level', 222), ('intake', 214), ('pharmacokinetic', 199), ('antibiotic', 196), ('concentration', 195), ('alcohol', 188), ('use', 174), ('diuretic', 171), ('agent', 167), ('agenerase', 165), ('dose', 162), ('acetaminophen', 155), ('*', 155)]
# e1_e2_under_same_verb 83 0.0038509720224562706 %
# e1_e2_under_same_word 6350 0.294622558344546 %
# e1_under_e2 168 0.007794738551477752 %
# e2_under_e1 1554 0.07210133160116922 %
# total 21553
# -----------------------------------------------

# %%
type_to_check = ''
word_to_check = ''
dict_to_check = 'clue_words' # clue_words, sentence_words, e1_under, e2_under
print(drug_dict[type_to_check][dict_to_check][word_to_check])
print(drug_dict[type_to_check]['total'])

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-d8e2034aec35> in <module>
# ----> 1 print(sorted(drug_dict['effect']['clue_words'], key=lambda item: item[1]))
#
# <ipython-input-24-d8e2034aec35> in <lambda>(item)
# ----> 1 print(sorted(drug_dict['effect']['clue_words'], key=lambda item: item[1]))
#
# IndexError: string index out of range
